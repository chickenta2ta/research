# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt

# %%
from google.colab import drive


drive.mount("/content/drive")

# %%
# !python train.py --weights yolov5x.pt --data "/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/data/eggplant.yaml" --epochs 1500 --batch-size 4 --imgsz 1088

# %%
# !cp "/content/yolov5/runs/train/exp/weights/best.pt" "/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/model/best_20221203.pt"

# %%
# !python val.py --data "/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/data/eggplant.yaml" --weights "/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/model/best_20221203.pt" --task test
# Out:
# val: data=/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/data/eggplant.yaml, weights=['/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/model/best_20221203.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-23-g5dc1ce4 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 18.4MB/s]
# test: Scanning /content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/data/test... 45 images, 0 backgrounds, 0 corrupt: 100% 45/45 [00:09<00:00,  4.56it/s]
# ...

# %%
# !python detect.py --weights "/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/model/best_20221203.pt" --source "/content/drive/My Drive/Colab Notebooks/Research/Processed Data/20221117/14AB_BACK_before/images/*.jpg"
# Out:
# detect: weights=['/content/drive/My Drive/Colab Notebooks/Research/Yield Prediction Using YOLOv5/model/best_20221203.pt'], source=/content/drive/My Drive/Colab Notebooks/Research/Processed Data/20221117/14AB_BACK_before/images/*.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-21-ga1b6e79 Python-3.8.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# image 1/939 /content/drive/My Drive/Colab Notebooks/Research/Processed Data/20221117/14AB_BACK_before/images/1002.jpg: 640x384 19 eggplants, 56.5ms
# ...
