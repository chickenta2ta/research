# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt

# %%
from google.colab import drive


drive.mount("/content/drive")

# %%
# !python train.py --img 640 --batch 16 --epochs 1500 --data "/content/drive/My Drive/Colab Notebooks/Research/Eggplant Flower Detection/data/eggplant_flower.yaml" --weights yolov5x.pt

# %%
# !cp "/content/yolov5/runs/train/exp/weights/best.pt" "/content/drive/My Drive/Colab Notebooks/Research/Eggplant Flower Detection/model"

# %%
# !python val.py --data "/content/drive/My Drive/Colab Notebooks/Research/Eggplant Flower Detection/data/eggplant_flower.yaml" --weights "/content/drive/My Drive/Colab Notebooks/Research/Eggplant Flower Detection/model/best.pt" --task test

# %%
# !python detect.py --weights "/content/drive/My Drive/Colab Notebooks/Research/Eggplant Flower Detection/model/best.pt" --source "/content/drive/My Drive/Colab Notebooks/Research/Eggplant Flower Detection/data/test/*.jpg"
